# %% [markdown]
# ## Imports

# %%
import requests
from bs4 import BeautifulSoup
import os
from astropy.io import fits
from astropy.time import Time
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Parameters

# %%
name = "SN2023cv"

# %% [markdown]
# ## Downloading FITS Files

# %%
base_url = "https://spt3g.ncsa.illinois.edu/files/jobs/e508c213baed4cfaa4d764685ed3e771/out/SN2023cv/"

download_folder = f"/Volumes/Memorex USB/{name}/fits_files"
os.makedirs(download_folder, exist_ok=True)


response = requests.get(base_url)
response.raise_for_status()
soup = BeautifulSoup(response.text, "html.parser")

file_links = [
    base_url + link["href"]
    for link in soup.find_all("a", href=True)
    if not link["href"].startswith("?") and not link["href"].endswith("/")
]

print(f"Found {len(file_links)} files to download.")

for idx, file_url in enumerate(file_links, start=1):
    file_name = os.path.basename(file_url)
    save_path = os.path.join(download_folder, file_name)

    try:
        with requests.get(file_url, stream=True) as r:
            r.raise_for_status()
            with open(save_path, "wb") as f:
                for chunk in r.iter_content(chunk_size=8192):
                    f.write(chunk)
        print(f"({idx}/{len(file_links)}) Downloaded: {file_name}")
    except Exception as e:
        print(f"Error downloading {file_name}: {e}")
# Out:
# Found 138 files to download.
# (1/138) Downloaded: SN2023cv_150GHz_231400425_psth.fits
# (2/138) Downloaded: SN2023cv_150GHz_231407529_psth.fits
# (3/138) Downloaded: SN2023cv_150GHz_231414634_psth.fits
# (4/138) Downloaded: SN2023cv_150GHz_231422500_psth.fits
# (5/138) Downloaded: SN2023cv_150GHz_231429684_psth.fits
# (6/138) Downloaded: SN2023cv_150GHz_231436791_psth.fits
# (7/138) Downloaded: SN2023cv_150GHz_231443896_psth.fits
# (8/138) Downloaded: SN2023cv_150GHz_231722991_psth.fits
# (9/138) Downloaded: SN2023cv_150GHz_231730095_psth.fits
# (10/138) Downloaded: SN2023cv_150GHz_231737199_psth.fits
# (11/138) Downloaded: SN2023cv_150GHz_231745061_psth.fits
# (12/138) Downloaded: SN2023cv_150GHz_231752167_psth.fits
# (13/138) Downloaded: SN2023cv_150GHz_231759273_psth.fits
# (14/138) Downloaded: SN2023cv_150GHz_231766378_psth.fits
# (15/138) Downloaded: SN2023cv_150GHz_233740805_psth.fits
# (16/138) Downloaded: SN2023cv_150GHz_233747909_psth.fits
# (17/138) Downloaded: SN2023cv_150GHz_233755012_psth.fits
# (18/138) Downloaded: SN2023cv_150GHz_233762952_psth.fits
# (19/138) Downloaded: SN2023cv_150GHz_233770057_psth.fits
# (20/138) Downloaded: SN2023cv_150GHz_233777161_psth.fits
# (21/138) Downloaded: SN2023cv_150GHz_233784263_psth.fits
# (22/138) Downloaded: SN2023cv_150GHz_234010493_psth.fits
# (23/138) Downloaded: SN2023cv_150GHz_234017677_psth.fits
# (24/138) Downloaded: SN2023cv_150GHz_234024782_psth.fits
# (25/138) Downloaded: SN2023cv_150GHz_234032642_psth.fits
# (26/138) Downloaded: SN2023cv_150GHz_234039747_psth.fits
# (27/138) Downloaded: SN2023cv_150GHz_234046853_psth.fits
# (28/138) Downloaded: SN2023cv_150GHz_234053957_psth.fits
# (29/138) Downloaded: SN2023cv_150GHz_236084700_psth.fits
# (30/138) Downloaded: SN2023cv_150GHz_236091804_psth.fits
# (31/138) Downloaded: SN2023cv_150GHz_236098908_psth.fits
# (32/138) Downloaded: SN2023cv_150GHz_236106770_psth.fits
# (33/138) Downloaded: SN2023cv_150GHz_236113875_psth.fits
# (34/138) Downloaded: SN2023cv_150GHz_236120980_psth.fits
# (35/138) Downloaded: SN2023cv_150GHz_236128085_psth.fits
# (36/138) Downloaded: SN2023cv_150GHz_236334066_psth.fits
# (37/138) Downloaded: SN2023cv_150GHz_236341249_psth.fits
# (38/138) Downloaded: SN2023cv_150GHz_236348351_psth.fits
# (39/138) Downloaded: SN2023cv_150GHz_236356211_psth.fits
# (40/138) Downloaded: SN2023cv_150GHz_236363314_psth.fits
# (41/138) Downloaded: SN2023cv_150GHz_236370420_psth.fits
# (42/138) Downloaded: SN2023cv_150GHz_236377526_psth.fits
# (43/138) Downloaded: SN2023cv_150GHz_238539904_psth.fits
# (44/138) Downloaded: SN2023cv_150GHz_238547007_psth.fits
# (45/138) Downloaded: SN2023cv_150GHz_238554112_psth.fits
# (46/138) Downloaded: SN2023cv_150GHz_238561975_psth.fits
# (47/138) Downloaded: SN2023cv_150GHz_238569078_psth.fits
# (48/138) Downloaded: SN2023cv_150GHz_238576181_psth.fits
# (49/138) Downloaded: SN2023cv_150GHz_238583367_psth.fits
# (50/138) Downloaded: SN2023cv_150GHz_240756948_psth.fits
# (51/138) Downloaded: SN2023cv_150GHz_240764036_psth.fits
# (52/138) Downloaded: SN2023cv_150GHz_240771125_psth.fits
# (53/138) Downloaded: SN2023cv_150GHz_240778968_psth.fits
# (54/138) Downloaded: SN2023cv_150GHz_240787080_psth.fits
# (55/138) Downloaded: SN2023cv_150GHz_240794167_psth.fits
# (56/138) Downloaded: SN2023cv_150GHz_240801256_psth.fits
# (57/138) Downloaded: SN2023cv_150GHz_241025708_psth.fits
# (58/138) Downloaded: SN2023cv_150GHz_241032796_psth.fits
# (59/138) Downloaded: SN2023cv_150GHz_241039885_psth.fits
# (60/138) Downloaded: SN2023cv_150GHz_241047728_psth.fits
# (61/138) Downloaded: SN2023cv_150GHz_241054815_psth.fits
# (62/138) Downloaded: SN2023cv_150GHz_241061903_psth.fits
# (63/138) Downloaded: SN2023cv_150GHz_241068991_psth.fits
# (64/138) Downloaded: SN2023cv_150GHz_243310144_psth.fits
# (65/138) Downloaded: SN2023cv_150GHz_243317233_psth.fits
# (66/138) Downloaded: SN2023cv_150GHz_243324403_psth.fits
# (67/138) Downloaded: SN2023cv_150GHz_243332247_psth.fits
# (68/138) Downloaded: SN2023cv_150GHz_243339336_psth.fits
# (69/138) Downloaded: SN2023cv_150GHz_243346427_psth.fits
# (70/138) Downloaded: SN2023cv_220GHz_231400425_psth.fits
# (71/138) Downloaded: SN2023cv_220GHz_231407529_psth.fits
# (72/138) Downloaded: SN2023cv_220GHz_231414634_psth.fits
# (73/138) Downloaded: SN2023cv_220GHz_231422500_psth.fits
# (74/138) Downloaded: SN2023cv_220GHz_231429684_psth.fits
# (75/138) Downloaded: SN2023cv_220GHz_231436791_psth.fits
# (76/138) Downloaded: SN2023cv_220GHz_231443896_psth.fits
# (77/138) Downloaded: SN2023cv_220GHz_231722991_psth.fits
# (78/138) Downloaded: SN2023cv_220GHz_231730095_psth.fits
# (79/138) Downloaded: SN2023cv_220GHz_231737199_psth.fits
# (80/138) Downloaded: SN2023cv_220GHz_231745061_psth.fits
# (81/138) Downloaded: SN2023cv_220GHz_231752167_psth.fits
# (82/138) Downloaded: SN2023cv_220GHz_231759273_psth.fits
# (83/138) Downloaded: SN2023cv_220GHz_231766378_psth.fits
# (84/138) Downloaded: SN2023cv_220GHz_233740805_psth.fits
# (85/138) Downloaded: SN2023cv_220GHz_233747909_psth.fits
# (86/138) Downloaded: SN2023cv_220GHz_233755012_psth.fits
# (87/138) Downloaded: SN2023cv_220GHz_233762952_psth.fits
# (88/138) Downloaded: SN2023cv_220GHz_233770057_psth.fits
# (89/138) Downloaded: SN2023cv_220GHz_233777161_psth.fits
# (90/138) Downloaded: SN2023cv_220GHz_233784263_psth.fits
# (91/138) Downloaded: SN2023cv_220GHz_234010493_psth.fits
# (92/138) Downloaded: SN2023cv_220GHz_234017677_psth.fits
# (93/138) Downloaded: SN2023cv_220GHz_234024782_psth.fits
# (94/138) Downloaded: SN2023cv_220GHz_234032642_psth.fits
# (95/138) Downloaded: SN2023cv_220GHz_234039747_psth.fits
# (96/138) Downloaded: SN2023cv_220GHz_234046853_psth.fits
# (97/138) Downloaded: SN2023cv_220GHz_234053957_psth.fits
# (98/138) Downloaded: SN2023cv_220GHz_236084700_psth.fits
# (99/138) Downloaded: SN2023cv_220GHz_236091804_psth.fits
# (100/138) Downloaded: SN2023cv_220GHz_236098908_psth.fits
# (101/138) Downloaded: SN2023cv_220GHz_236106770_psth.fits
# (102/138) Downloaded: SN2023cv_220GHz_236113875_psth.fits
# (103/138) Downloaded: SN2023cv_220GHz_236120980_psth.fits
# (104/138) Downloaded: SN2023cv_220GHz_236128085_psth.fits
# (105/138) Downloaded: SN2023cv_220GHz_236334066_psth.fits
# (106/138) Downloaded: SN2023cv_220GHz_236341249_psth.fits
# (107/138) Downloaded: SN2023cv_220GHz_236348351_psth.fits
# (108/138) Downloaded: SN2023cv_220GHz_236356211_psth.fits
# (109/138) Downloaded: SN2023cv_220GHz_236363314_psth.fits
# (110/138) Downloaded: SN2023cv_220GHz_236370420_psth.fits
# (111/138) Downloaded: SN2023cv_220GHz_236377526_psth.fits
# (112/138) Downloaded: SN2023cv_220GHz_238539904_psth.fits
# (113/138) Downloaded: SN2023cv_220GHz_238547007_psth.fits
# (114/138) Downloaded: SN2023cv_220GHz_238554112_psth.fits
# (115/138) Downloaded: SN2023cv_220GHz_238561975_psth.fits
# (116/138) Downloaded: SN2023cv_220GHz_238569078_psth.fits
# (117/138) Downloaded: SN2023cv_220GHz_238576181_psth.fits
# (118/138) Downloaded: SN2023cv_220GHz_238583367_psth.fits
# (119/138) Downloaded: SN2023cv_220GHz_240756948_psth.fits
# (120/138) Downloaded: SN2023cv_220GHz_240764036_psth.fits
# (121/138) Downloaded: SN2023cv_220GHz_240771125_psth.fits
# (122/138) Downloaded: SN2023cv_220GHz_240778968_psth.fits
# (123/138) Downloaded: SN2023cv_220GHz_240787080_psth.fits
# (124/138) Downloaded: SN2023cv_220GHz_240794167_psth.fits
# (125/138) Downloaded: SN2023cv_220GHz_240801256_psth.fits
# (126/138) Downloaded: SN2023cv_220GHz_241025708_psth.fits
# (127/138) Downloaded: SN2023cv_220GHz_241032796_psth.fits
# (128/138) Downloaded: SN2023cv_220GHz_241039885_psth.fits
# (129/138) Downloaded: SN2023cv_220GHz_241047728_psth.fits
# (130/138) Downloaded: SN2023cv_220GHz_241054815_psth.fits
# (131/138) Downloaded: SN2023cv_220GHz_241061903_psth.fits
# (132/138) Downloaded: SN2023cv_220GHz_241068991_psth.fits
# (133/138) Downloaded: SN2023cv_220GHz_243310144_psth.fits
# (134/138) Downloaded: SN2023cv_220GHz_243317233_psth.fits
# (135/138) Downloaded: SN2023cv_220GHz_243324403_psth.fits
# (136/138) Downloaded: SN2023cv_220GHz_243332247_psth.fits
# (137/138) Downloaded: SN2023cv_220GHz_243339336_psth.fits
# (138/138) Downloaded: SN2023cv_220GHz_243346427_psth.fits

# %% [markdown]
# ## Inputs and Outputs

# %%
input_folder = download_folder
output_csv = "/Users/Djslime07/SPT_VSCode/CSV's/obs_values.csv"

# %% [markdown]
# ## FITS Plotter

# %%
for fits_file in os.listdir(input_folder):
    if fits_file.endswith(".fits"):
        fits_path = os.path.join(input_folder, fits_file)

        if fits_file.startswith("._"):
            continue

        try:
            with fits.open(fits_path, ignore_missing_simple=True) as hdul:
                data = hdul[0].data
                header = hdul[0].header
                date_beg = header.get('DATE-BEG', 'Unknown')
                date_end = header.get('DATE-END', 'Unknown')
                object_name = header.get('OBJECT', 'Unknown')
                band = header.get('BAND', 'Unknown')
                print(f"Processing {fits_file} | DATE-BEG: {date_beg} | BAND: {band}")

                try:
                    mjd = Time(date_beg).mjd
                except Exception as e:
                    print(f"Skipping {fits_file}: Invalid DATE-BEG format. Error: {e}")
                    continue

                if data is None:
                    print(f"Skipping {fits_file}: No image data found.")
                    continue

                data = np.nan_to_num(data)
                if np.max(data) == 0:
                    print(f"Skipping {fits_file}: Peak flux is zero.")
                    continue


                if "fltd" in fits_file:
                    suffix = "Filtered"
                elif "psth" in fits_file:
                    suffix = "Passthrough"
                else:
                    print(f"Skipping {fits_file}: Unknown file type.")
                    continue

                peak_flux = np.max(data)
                rms_temp = np.std(data)
                keep = np.abs(data) <= 3 * rms_temp
                rms = np.std(data[keep])
                vmin, vmax = np.percentile(data, [1, 99])


                band_output_folder = f"/Volumes/Memorex USB/{name}/PNG_{name}_{band}"
                os.makedirs(band_output_folder, exist_ok=True)

                plt.figure()
                plt.imshow(data, origin='lower', vmin=vmin, vmax=vmax)
                plt.colorbar(label='Flux [mK]')
                plt.title(
                    f"{object_name} ({band}) MJD: {mjd:.5f} | Peak Flux: {peak_flux:.4} mK | Flux RMS: {rms:.4f} mK",
                    fontsize=9.5
                )
                png_filename = os.path.join(band_output_folder, f"{mjd:.5f}_{suffix}.png")
                plt.savefig(png_filename)
                plt.close()


                with open(output_csv, "a") as f:
                    print(f"{object_name},{date_beg},{date_end},{mjd},{peak_flux},{rms},{band}", file=f)

            print(f"Converted: {fits_file} -> {png_filename}")
        except Exception as e:
            print(f"Error processing {fits_file}: {e}")
# Out:
# Processing SN2023cv_150GHz_231400425_psth.fits | DATE-BEG: 2024-05-02T05:53:46.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_231400425_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60432.24567_Passthrough.png
# Processing SN2023cv_150GHz_231407529_psth.fits | DATE-BEG: 2024-05-02T07:52:10.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_231407529_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60432.32789_Passthrough.png
# Processing SN2023cv_150GHz_231414634_psth.fits | DATE-BEG: 2024-05-02T09:50:35.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_231414634_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60432.41013_Passthrough.png
# Processing SN2023cv_150GHz_231422500_psth.fits | DATE-BEG: 2024-05-02T12:01:41.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_231422500_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60432.50117_Passthrough.png
# Processing SN2023cv_150GHz_231429684_psth.fits | DATE-BEG: 2024-05-02T14:01:25.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_231429684_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60432.58432_Passthrough.png
# Processing SN2023cv_150GHz_231436791_psth.fits | DATE-BEG: 2024-05-02T15:59:52.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_231436791_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60432.66657_Passthrough.png
# Processing SN2023cv_150GHz_231443896_psth.fits | DATE-BEG: 2024-05-02T17:58:17.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_231443896_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60432.74881_Passthrough.png
# Processing SN2023cv_150GHz_231722991_psth.fits | DATE-BEG: 2024-05-05T23:29:52.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_231722991_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60435.97907_Passthrough.png
# Processing SN2023cv_150GHz_231730095_psth.fits | DATE-BEG: 2024-05-06T01:28:16.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_231730095_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60436.06130_Passthrough.png
# Processing SN2023cv_150GHz_231737199_psth.fits | DATE-BEG: 2024-05-06T03:26:40.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_231737199_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60436.14352_Passthrough.png
# Processing SN2023cv_150GHz_231745061_psth.fits | DATE-BEG: 2024-05-06T05:37:42.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_231745061_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60436.23451_Passthrough.png
# Processing SN2023cv_150GHz_231752167_psth.fits | DATE-BEG: 2024-05-06T07:36:08.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_231752167_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60436.31676_Passthrough.png
# Processing SN2023cv_150GHz_231759273_psth.fits | DATE-BEG: 2024-05-06T09:34:34.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_231759273_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60436.39900_Passthrough.png
# Processing SN2023cv_150GHz_231766378_psth.fits | DATE-BEG: 2024-05-06T11:32:59.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_231766378_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60436.48124_Passthrough.png
# Processing SN2023cv_150GHz_233740805_psth.fits | DATE-BEG: 2024-05-29T08:00:06.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_233740805_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60459.33340_Passthrough.png
# Processing SN2023cv_150GHz_233747909_psth.fits | DATE-BEG: 2024-05-29T09:58:30.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_233747909_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60459.41563_Passthrough.png
# Processing SN2023cv_150GHz_233755012_psth.fits | DATE-BEG: 2024-05-29T11:56:53.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_233755012_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60459.49784_Passthrough.png
# Processing SN2023cv_150GHz_233762952_psth.fits | DATE-BEG: 2024-05-29T14:09:13.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_233762952_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60459.58973_Passthrough.png
# Processing SN2023cv_150GHz_233770057_psth.fits | DATE-BEG: 2024-05-29T16:07:38.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_233770057_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60459.67197_Passthrough.png
# Processing SN2023cv_150GHz_233777161_psth.fits | DATE-BEG: 2024-05-29T18:06:02.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_233777161_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60459.75419_Passthrough.png
# Processing SN2023cv_150GHz_233784263_psth.fits | DATE-BEG: 2024-05-29T20:04:24.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_233784263_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60459.83639_Passthrough.png
# Processing SN2023cv_150GHz_234010493_psth.fits | DATE-BEG: 2024-06-01T10:54:54.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_234010493_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60462.45479_Passthrough.png
# Processing SN2023cv_150GHz_234017677_psth.fits | DATE-BEG: 2024-06-01T12:54:38.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_234017677_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60462.53794_Passthrough.png
# Processing SN2023cv_150GHz_234024782_psth.fits | DATE-BEG: 2024-06-01T14:53:03.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_234024782_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60462.62017_Passthrough.png
# Processing SN2023cv_150GHz_234032642_psth.fits | DATE-BEG: 2024-06-01T17:04:03.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_234032642_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60462.71115_Passthrough.png
# Processing SN2023cv_150GHz_234039747_psth.fits | DATE-BEG: 2024-06-01T19:02:28.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_234039747_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60462.79338_Passthrough.png
# Processing SN2023cv_150GHz_234046853_psth.fits | DATE-BEG: 2024-06-01T21:00:54.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_234046853_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60462.87563_Passthrough.png
# Processing SN2023cv_150GHz_234053957_psth.fits | DATE-BEG: 2024-06-01T22:59:18.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_234053957_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60462.95785_Passthrough.png
# Processing SN2023cv_150GHz_236084700_psth.fits | DATE-BEG: 2024-06-25T11:05:01.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_236084700_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60486.46182_Passthrough.png
# Processing SN2023cv_150GHz_236091804_psth.fits | DATE-BEG: 2024-06-25T13:03:25.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_236091804_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60486.54404_Passthrough.png
# Processing SN2023cv_150GHz_236098908_psth.fits | DATE-BEG: 2024-06-25T15:01:49.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_236098908_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60486.62626_Passthrough.png
# Processing SN2023cv_150GHz_236106770_psth.fits | DATE-BEG: 2024-06-25T17:12:51.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_236106770_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60486.71726_Passthrough.png
# Processing SN2023cv_150GHz_236113875_psth.fits | DATE-BEG: 2024-06-25T19:11:16.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_236113875_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60486.79949_Passthrough.png
# Processing SN2023cv_150GHz_236120980_psth.fits | DATE-BEG: 2024-06-25T21:09:41.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_236120980_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60486.88172_Passthrough.png
# Processing SN2023cv_150GHz_236128085_psth.fits | DATE-BEG: 2024-06-25T23:08:06.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_236128085_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60486.96396_Passthrough.png
# Processing SN2023cv_150GHz_236334066_psth.fits | DATE-BEG: 2024-06-28T08:21:07.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_236334066_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60489.34800_Passthrough.png
# Processing SN2023cv_150GHz_236341249_psth.fits | DATE-BEG: 2024-06-28T10:20:50.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_236341249_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60489.43113_Passthrough.png
# Processing SN2023cv_150GHz_236348351_psth.fits | DATE-BEG: 2024-06-28T12:19:12.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_236348351_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60489.51333_Passthrough.png
# Processing SN2023cv_150GHz_236356211_psth.fits | DATE-BEG: 2024-06-28T14:30:12.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_236356211_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60489.60431_Passthrough.png
# Processing SN2023cv_150GHz_236363314_psth.fits | DATE-BEG: 2024-06-28T16:28:35.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_236363314_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60489.68652_Passthrough.png
# Processing SN2023cv_150GHz_236370420_psth.fits | DATE-BEG: 2024-06-28T18:27:01.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_236370420_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60489.76876_Passthrough.png
# Processing SN2023cv_150GHz_236377526_psth.fits | DATE-BEG: 2024-06-28T20:25:27.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_236377526_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60489.85101_Passthrough.png
# Processing SN2023cv_150GHz_238539904_psth.fits | DATE-BEG: 2024-07-23T21:05:05.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_238539904_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60514.87853_Passthrough.png
# Processing SN2023cv_150GHz_238547007_psth.fits | DATE-BEG: 2024-07-23T23:03:28.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_238547007_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60514.96074_Passthrough.png
# Processing SN2023cv_150GHz_238554112_psth.fits | DATE-BEG: 2024-07-24T01:01:53.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_238554112_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60515.04297_Passthrough.png
# Processing SN2023cv_150GHz_238561975_psth.fits | DATE-BEG: 2024-07-24T03:12:56.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_238561975_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60515.13398_Passthrough.png
# Processing SN2023cv_150GHz_238569078_psth.fits | DATE-BEG: 2024-07-24T05:11:19.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_238569078_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60515.21619_Passthrough.png
# Processing SN2023cv_150GHz_238576181_psth.fits | DATE-BEG: 2024-07-24T07:09:42.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_238576181_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60515.29840_Passthrough.png
# Processing SN2023cv_150GHz_238583367_psth.fits | DATE-BEG: 2024-07-24T09:09:28.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_238583367_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60515.38157_Passthrough.png
# Processing SN2023cv_150GHz_240756948_psth.fits | DATE-BEG: 2024-08-18T12:55:49.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_240756948_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60540.53876_Passthrough.png
# Processing SN2023cv_150GHz_240764036_psth.fits | DATE-BEG: 2024-08-18T14:53:57.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_240764036_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60540.62080_Passthrough.png
# Processing SN2023cv_150GHz_240771125_psth.fits | DATE-BEG: 2024-08-18T16:52:06.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_240771125_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60540.70285_Passthrough.png
# Processing SN2023cv_150GHz_240778968_psth.fits | DATE-BEG: 2024-08-18T19:02:49.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_240778968_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60540.79362_Passthrough.png
# Processing SN2023cv_150GHz_240787080_psth.fits | DATE-BEG: 2024-08-18T21:18:01.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_240787080_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60540.88751_Passthrough.png
# Processing SN2023cv_150GHz_240794167_psth.fits | DATE-BEG: 2024-08-18T23:16:08.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_240794167_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60540.96954_Passthrough.png
# Processing SN2023cv_150GHz_240801256_psth.fits | DATE-BEG: 2024-08-19T01:14:17.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_240801256_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60541.05159_Passthrough.png
# Processing SN2023cv_150GHz_241025708_psth.fits | DATE-BEG: 2024-08-21T15:35:09.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_241025708_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60543.64941_Passthrough.png
# Processing SN2023cv_150GHz_241032796_psth.fits | DATE-BEG: 2024-08-21T17:33:17.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_241032796_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60543.73145_Passthrough.png
# Processing SN2023cv_150GHz_241039885_psth.fits | DATE-BEG: 2024-08-21T19:31:26.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_241039885_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60543.81350_Passthrough.png
# Processing SN2023cv_150GHz_241047728_psth.fits | DATE-BEG: 2024-08-21T21:42:09.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_241047728_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60543.90427_Passthrough.png
# Processing SN2023cv_150GHz_241054815_psth.fits | DATE-BEG: 2024-08-21T23:40:16.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_241054815_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60543.98630_Passthrough.png
# Processing SN2023cv_150GHz_241061903_psth.fits | DATE-BEG: 2024-08-22T01:38:24.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_241061903_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60544.06833_Passthrough.png
# Processing SN2023cv_150GHz_241068991_psth.fits | DATE-BEG: 2024-08-22T03:36:32.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_241068991_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60544.15037_Passthrough.png
# Processing SN2023cv_150GHz_243310144_psth.fits | DATE-BEG: 2024-09-17T02:09:05.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_243310144_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60570.08964_Passthrough.png
# Processing SN2023cv_150GHz_243317233_psth.fits | DATE-BEG: 2024-09-17T04:07:14.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_243317233_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60570.17169_Passthrough.png
# Processing SN2023cv_150GHz_243324403_psth.fits | DATE-BEG: 2024-09-17T06:06:44.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_243324403_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60570.25468_Passthrough.png
# Processing SN2023cv_150GHz_243332247_psth.fits | DATE-BEG: 2024-09-17T08:17:28.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_243332247_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60570.34546_Passthrough.png
# Processing SN2023cv_150GHz_243339336_psth.fits | DATE-BEG: 2024-09-17T10:15:37.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_243339336_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60570.42751_Passthrough.png
# Processing SN2023cv_150GHz_243346427_psth.fits | DATE-BEG: 2024-09-17T12:13:48.000 | BAND: 150GHz
# Converted: SN2023cv_150GHz_243346427_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_150GHz/60570.50958_Passthrough.png
# Processing SN2023cv_220GHz_231400425_psth.fits | DATE-BEG: 2024-05-02T05:53:46.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_231400425_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60432.24567_Passthrough.png
# Processing SN2023cv_220GHz_231407529_psth.fits | DATE-BEG: 2024-05-02T07:52:10.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_231407529_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60432.32789_Passthrough.png
# Processing SN2023cv_220GHz_231414634_psth.fits | DATE-BEG: 2024-05-02T09:50:35.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_231414634_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60432.41013_Passthrough.png
# Processing SN2023cv_220GHz_231422500_psth.fits | DATE-BEG: 2024-05-02T12:01:41.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_231422500_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60432.50117_Passthrough.png
# Processing SN2023cv_220GHz_231429684_psth.fits | DATE-BEG: 2024-05-02T14:01:25.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_231429684_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60432.58432_Passthrough.png
# Processing SN2023cv_220GHz_231436791_psth.fits | DATE-BEG: 2024-05-02T15:59:52.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_231436791_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60432.66657_Passthrough.png
# Processing SN2023cv_220GHz_231443896_psth.fits | DATE-BEG: 2024-05-02T17:58:17.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_231443896_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60432.74881_Passthrough.png
# Processing SN2023cv_220GHz_231722991_psth.fits | DATE-BEG: 2024-05-05T23:29:52.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_231722991_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60435.97907_Passthrough.png
# Processing SN2023cv_220GHz_231730095_psth.fits | DATE-BEG: 2024-05-06T01:28:16.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_231730095_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60436.06130_Passthrough.png
# Processing SN2023cv_220GHz_231737199_psth.fits | DATE-BEG: 2024-05-06T03:26:40.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_231737199_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60436.14352_Passthrough.png
# Processing SN2023cv_220GHz_231745061_psth.fits | DATE-BEG: 2024-05-06T05:37:42.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_231745061_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60436.23451_Passthrough.png
# Processing SN2023cv_220GHz_231752167_psth.fits | DATE-BEG: 2024-05-06T07:36:08.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_231752167_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60436.31676_Passthrough.png
# Processing SN2023cv_220GHz_231759273_psth.fits | DATE-BEG: 2024-05-06T09:34:34.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_231759273_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60436.39900_Passthrough.png
# Processing SN2023cv_220GHz_231766378_psth.fits | DATE-BEG: 2024-05-06T11:32:59.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_231766378_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60436.48124_Passthrough.png
# Processing SN2023cv_220GHz_233740805_psth.fits | DATE-BEG: 2024-05-29T08:00:06.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_233740805_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60459.33340_Passthrough.png
# Processing SN2023cv_220GHz_233747909_psth.fits | DATE-BEG: 2024-05-29T09:58:30.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_233747909_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60459.41563_Passthrough.png
# Processing SN2023cv_220GHz_233755012_psth.fits | DATE-BEG: 2024-05-29T11:56:53.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_233755012_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60459.49784_Passthrough.png
# Processing SN2023cv_220GHz_233762952_psth.fits | DATE-BEG: 2024-05-29T14:09:13.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_233762952_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60459.58973_Passthrough.png
# Processing SN2023cv_220GHz_233770057_psth.fits | DATE-BEG: 2024-05-29T16:07:38.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_233770057_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60459.67197_Passthrough.png
# Processing SN2023cv_220GHz_233777161_psth.fits | DATE-BEG: 2024-05-29T18:06:02.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_233777161_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60459.75419_Passthrough.png
# Processing SN2023cv_220GHz_233784263_psth.fits | DATE-BEG: 2024-05-29T20:04:24.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_233784263_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60459.83639_Passthrough.png
# Processing SN2023cv_220GHz_234010493_psth.fits | DATE-BEG: 2024-06-01T10:54:54.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_234010493_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60462.45479_Passthrough.png
# Processing SN2023cv_220GHz_234017677_psth.fits | DATE-BEG: 2024-06-01T12:54:38.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_234017677_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60462.53794_Passthrough.png
# Processing SN2023cv_220GHz_234024782_psth.fits | DATE-BEG: 2024-06-01T14:53:03.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_234024782_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60462.62017_Passthrough.png
# Processing SN2023cv_220GHz_234032642_psth.fits | DATE-BEG: 2024-06-01T17:04:03.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_234032642_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60462.71115_Passthrough.png
# Processing SN2023cv_220GHz_234039747_psth.fits | DATE-BEG: 2024-06-01T19:02:28.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_234039747_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60462.79338_Passthrough.png
# Processing SN2023cv_220GHz_234046853_psth.fits | DATE-BEG: 2024-06-01T21:00:54.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_234046853_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60462.87563_Passthrough.png
# Processing SN2023cv_220GHz_234053957_psth.fits | DATE-BEG: 2024-06-01T22:59:18.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_234053957_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60462.95785_Passthrough.png
# Processing SN2023cv_220GHz_236084700_psth.fits | DATE-BEG: 2024-06-25T11:05:01.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_236084700_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60486.46182_Passthrough.png
# Processing SN2023cv_220GHz_236091804_psth.fits | DATE-BEG: 2024-06-25T13:03:25.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_236091804_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60486.54404_Passthrough.png
# Processing SN2023cv_220GHz_236098908_psth.fits | DATE-BEG: 2024-06-25T15:01:49.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_236098908_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60486.62626_Passthrough.png
# Processing SN2023cv_220GHz_236106770_psth.fits | DATE-BEG: 2024-06-25T17:12:51.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_236106770_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60486.71726_Passthrough.png
# Processing SN2023cv_220GHz_236113875_psth.fits | DATE-BEG: 2024-06-25T19:11:16.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_236113875_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60486.79949_Passthrough.png
# Processing SN2023cv_220GHz_236120980_psth.fits | DATE-BEG: 2024-06-25T21:09:41.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_236120980_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60486.88172_Passthrough.png
# Processing SN2023cv_220GHz_236128085_psth.fits | DATE-BEG: 2024-06-25T23:08:06.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_236128085_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60486.96396_Passthrough.png
# Processing SN2023cv_220GHz_236334066_psth.fits | DATE-BEG: 2024-06-28T08:21:07.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_236334066_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60489.34800_Passthrough.png
# Processing SN2023cv_220GHz_236341249_psth.fits | DATE-BEG: 2024-06-28T10:20:50.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_236341249_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60489.43113_Passthrough.png
# Processing SN2023cv_220GHz_236348351_psth.fits | DATE-BEG: 2024-06-28T12:19:12.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_236348351_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60489.51333_Passthrough.png
# Processing SN2023cv_220GHz_236356211_psth.fits | DATE-BEG: 2024-06-28T14:30:12.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_236356211_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60489.60431_Passthrough.png
# Processing SN2023cv_220GHz_236363314_psth.fits | DATE-BEG: 2024-06-28T16:28:35.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_236363314_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60489.68652_Passthrough.png
# Processing SN2023cv_220GHz_236370420_psth.fits | DATE-BEG: 2024-06-28T18:27:01.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_236370420_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60489.76876_Passthrough.png
# Processing SN2023cv_220GHz_236377526_psth.fits | DATE-BEG: 2024-06-28T20:25:27.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_236377526_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60489.85101_Passthrough.png
# Processing SN2023cv_220GHz_238539904_psth.fits | DATE-BEG: 2024-07-23T21:05:05.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_238539904_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60514.87853_Passthrough.png
# Processing SN2023cv_220GHz_238547007_psth.fits | DATE-BEG: 2024-07-23T23:03:28.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_238547007_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60514.96074_Passthrough.png
# Processing SN2023cv_220GHz_238554112_psth.fits | DATE-BEG: 2024-07-24T01:01:53.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_238554112_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60515.04297_Passthrough.png
# Processing SN2023cv_220GHz_238561975_psth.fits | DATE-BEG: 2024-07-24T03:12:56.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_238561975_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60515.13398_Passthrough.png
# Processing SN2023cv_220GHz_238569078_psth.fits | DATE-BEG: 2024-07-24T05:11:19.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_238569078_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60515.21619_Passthrough.png
# Processing SN2023cv_220GHz_238576181_psth.fits | DATE-BEG: 2024-07-24T07:09:42.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_238576181_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60515.29840_Passthrough.png
# Processing SN2023cv_220GHz_238583367_psth.fits | DATE-BEG: 2024-07-24T09:09:28.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_238583367_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60515.38157_Passthrough.png
# Processing SN2023cv_220GHz_240756948_psth.fits | DATE-BEG: 2024-08-18T12:55:49.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_240756948_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60540.53876_Passthrough.png
# Processing SN2023cv_220GHz_240764036_psth.fits | DATE-BEG: 2024-08-18T14:53:57.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_240764036_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60540.62080_Passthrough.png
# Processing SN2023cv_220GHz_240771125_psth.fits | DATE-BEG: 2024-08-18T16:52:06.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_240771125_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60540.70285_Passthrough.png
# Processing SN2023cv_220GHz_240778968_psth.fits | DATE-BEG: 2024-08-18T19:02:49.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_240778968_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60540.79362_Passthrough.png
# Processing SN2023cv_220GHz_240787080_psth.fits | DATE-BEG: 2024-08-18T21:18:01.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_240787080_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60540.88751_Passthrough.png
# Processing SN2023cv_220GHz_240794167_psth.fits | DATE-BEG: 2024-08-18T23:16:08.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_240794167_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60540.96954_Passthrough.png
# Processing SN2023cv_220GHz_240801256_psth.fits | DATE-BEG: 2024-08-19T01:14:17.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_240801256_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60541.05159_Passthrough.png
# Processing SN2023cv_220GHz_241025708_psth.fits | DATE-BEG: 2024-08-21T15:35:09.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_241025708_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60543.64941_Passthrough.png
# Processing SN2023cv_220GHz_241032796_psth.fits | DATE-BEG: 2024-08-21T17:33:17.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_241032796_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60543.73145_Passthrough.png
# Processing SN2023cv_220GHz_241039885_psth.fits | DATE-BEG: 2024-08-21T19:31:26.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_241039885_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60543.81350_Passthrough.png
# Processing SN2023cv_220GHz_241047728_psth.fits | DATE-BEG: 2024-08-21T21:42:09.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_241047728_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60543.90427_Passthrough.png
# Processing SN2023cv_220GHz_241054815_psth.fits | DATE-BEG: 2024-08-21T23:40:16.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_241054815_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60543.98630_Passthrough.png
# Processing SN2023cv_220GHz_241061903_psth.fits | DATE-BEG: 2024-08-22T01:38:24.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_241061903_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60544.06833_Passthrough.png
# Processing SN2023cv_220GHz_241068991_psth.fits | DATE-BEG: 2024-08-22T03:36:32.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_241068991_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60544.15037_Passthrough.png
# Processing SN2023cv_220GHz_243310144_psth.fits | DATE-BEG: 2024-09-17T02:09:05.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_243310144_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60570.08964_Passthrough.png
# Processing SN2023cv_220GHz_243317233_psth.fits | DATE-BEG: 2024-09-17T04:07:14.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_243317233_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60570.17169_Passthrough.png
# Processing SN2023cv_220GHz_243324403_psth.fits | DATE-BEG: 2024-09-17T06:06:44.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_243324403_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60570.25468_Passthrough.png
# Processing SN2023cv_220GHz_243332247_psth.fits | DATE-BEG: 2024-09-17T08:17:28.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_243332247_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60570.34546_Passthrough.png
# Processing SN2023cv_220GHz_243339336_psth.fits | DATE-BEG: 2024-09-17T10:15:37.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_243339336_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60570.42751_Passthrough.png
# Processing SN2023cv_220GHz_243346427_psth.fits | DATE-BEG: 2024-09-17T12:13:48.000 | BAND: 220GHz
# Converted: SN2023cv_220GHz_243346427_psth.fits -> /Volumes/Memorex USB/SN2023cv/PNG_SN2023cv_220GHz/60570.50958_Passthrough.png

# %% [markdown]
# ## Data Extraction

# %%
for fits_file in os.listdir(input_folder):
    if fits_file.endswith(".fits"):
        fits_path = os.path.join(input_folder, fits_file)

        if fits_file.startswith("._"):
            continue

        try:
            with fits.open(fits_path, ignore_missing_simple=True) as hdul:
                data = hdul[0].data
                header = hdul[0].header
                date_beg = header.get('DATE-BEG', 'Unknown')
                date_end = header.get('DATE-END', 'Unknown')
                object_name = header.get('OBJECT', 'Unknown')
                band = header.get('BAND', 'Unknown')
                print(f"Date:{date_beg}")

                try:
                    mjd = Time(date_beg).mjd
                except Exception as e:
                    print(f"Skipping {fits_file}: Invalid DATE-BEG format. Error: {e}")
                    continue

                if data is None:
                    print(f"Skipping {fits_file}: No image data found.")
                    continue

                data = np.nan_to_num(data)
                if np.max(data) == 0:
                    print(f"Skipping {fits_file}: Peak flux is zero.")
                    continue

                if "fltd" in fits_file:
                    suffix = "Filtered"
                elif "psth" in fits_file:
                    suffix = "Passthrough"
                else:
                    print(f"Skipping {fits_file}: Unknown file type.")
                    continue

                peak_flux = np.max(data)
                rms_temp = np.std(data)
                keep = np.abs(data) <= 3 * rms_temp
                rms = np.std(data[keep])

                with open(output_csv, "a") as f:
                    print(f"{date_beg}, {date_end}, {mjd} ,{peak_flux}, {rms}, {band}", file=f)
        except Exception as e:
            print(f"Error processing {fits_file}: {e}")
# Out:
# Error processing SN2019esa_220GHz_217786563_fltd.fits: Empty or corrupt FITS file
# Date:2023-11-26T18:36:03.000
# Error processing SN2019esa_220GHz_218515294_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_218523693_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_218532094_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_218541259_fltd.fits: buffer is too small for requested array
# Date:2023-12-05T12:14:20.000
# Error processing SN2019esa_220GHz_218558058_fltd.fits: buffer is too small for requested array
# Error processing SN2019esa_220GHz_218939212_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_218956010_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_218965177_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_218973576_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_218981975_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_219403104_fltd.fits: Empty or corrupt FITS file
# Date:2023-12-15T16:31:10.000
# Error processing SN2019esa_220GHz_219437554_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_219445953_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_219673129_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_219681528_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_219689927_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_219699177_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_220180191_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_220188590_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_220196989_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_220206154_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_220214638_fltd.fits: buffer is too small for requested array
# Error processing SN2019esa_220GHz_220223037_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_220443522_fltd.fits: Empty or corrupt FITS file
# Date:2023-12-27T12:38:42.000
# Error processing SN2019esa_220GHz_220460320_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_220469572_fltd.fits: Empty or corrupt FITS file
# Date:2023-12-27T19:52:53.000
# Error processing SN2019esa_220GHz_220486371_fltd.fits: Empty or corrupt FITS file
# Date:2024-01-12T12:52:01.000
# Error processing SN2019esa_220GHz_221843519_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_221852003_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_221861168_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_221869567_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_221877966_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_221903185_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_221919983_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_221929150_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_221937634_fltd.fits: Empty or corrupt FITS file
# Error processing SN2019esa_220GHz_221946033_fltd.fits: Empty or corrupt FITS file
# Date:yearly_collate_wideg
# Skipping SN2019esa_220GHz_yearly_collate_wideg_fltd.fits: Invalid DATE-BEG format. Error: Input values did not match any of the formats where the format keyword is optional:
# - 'datetime': Input values for datetime class must be datetime objects
# - 'ymdhms': input must be dict or table-like
# - 'iso': Time yearly_collate_wideg does not match iso format
# - 'isot': Time yearly_collate_wideg does not match isot format
# - 'yday': Time yearly_collate_wideg does not match yday format
# - 'datetime64': Input values for datetime64 class must be datetime64 objects
# - 'fits': Time yearly_collate_wideg does not match fits format
# - 'byear_str': Time yearly_collate_wideg does not match byear_str format
# - 'jyear_str': Time yearly_collate_wideg does not match jyear_str format
# - 'astropy_time': Input values for astropy_time class must all be the same astropy Time type.
# WARNING: File may have been truncated: actual file length (12288) is smaller than the expected size (23040) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (16384) is smaller than the expected size (23040) [astropy.io.fits.file]
# WARNING: AstropyDeprecationWarning: The indent function is deprecated and may be removed in a future version.
#         Use textwrap.indent() instead. [astropy.io.fits.hdu.hdulist]
# WARNING: VerifyWarning: Error validating header for HDU #0 (note: Astropy uses zero-based indexing).
#     Header size is not multiple of 2880: 8192
# There may be extra bytes after the last HDU or the file is corrupted. [astropy.io.fits.hdu.hdulist]
